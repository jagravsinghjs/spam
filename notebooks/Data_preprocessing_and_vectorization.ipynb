# %%
import pandas as pd

train_url = 'https://raw.githubusercontent.com/jagravsinghjs/spam/refs/heads/main/Scamouflage.json'
train= pd.read_json(train_url)

# %%
print(train.head())
print(train.columns)
print(train.value_counts())
# Out:
#                                                 text  label  \
# 0  Your one-time verification code is 849302. Thi...      0
# 1  Amazon Security: We noticed a new sign-in to y...      1
# 2  Hi Jessica, we reviewed your profile and belie...      1
# 3  Your Uber subscription has been successfully r...      0
# 4  Congratulations!! You've been pre-approved for...      1
#
#                  scam_type difficulty
# 0                     none       hard
# 1  password reset phishing     medium
# 2           job offer scam     medium
# 3     service confirmation     medium
# 4           job offer scam       easy
# Index(['text', 'label', 'scam_type', 'difficulty'], dtype='object')
# text                                                                                                                                 label  scam_type      difficulty
# v3rify your ID now to keep your account active. Failure to do so will lead to permanent cl0sure. bit.ly/acc-ver-99                   1      bank urgency   easy          1
# A charge of $0.00 was attempted at 'HOTEL-CHECK-IN' on your card. This is a common pre-authorization. No action is required.         0      none           hard          1
# A deposit of $50.00 was made to your checking account ending in 1234.                                                                0      none           easy          1
# A mandatory security upgrade is required for your mobile banking application. Please authenticate via the secure portal provided.    1      bank urgency   hard          1
# A new device 'iPhone 15' has just signed into your WhatsApp. If this wasn't you, click here to d3-regist3r it immediately.           1      impersonation  medium        1
#                                                                                                                                                                         ..
# ALERT!! Citibank security: Your debit card ending 1461 was used fraudulently. Click cutt.ly/hJ7x2 to dispute and secure acc0unt!     1      bank urgency   easy          1
# ALERT!! Chase security: Your debit card ending 7397 was used fraudulently. Click is.gd/mX8pQr to dispute and secure acc0unt!         1      bank urgency   easy          1
# ALERT!! Chase security: Your debit card ending 3068 was used fraudulently. Click tinyurl.com/y7h3k2q to dispute and secure acc0unt!  1      bank urgency   easy          1
# ALERT!! Chase security: Your debit card ending 2330 was used fraudulently. Click bit.ly/3xK9mP to dispute and secure acc0unt!        1      bank urgency   easy          1
# ALERT!! Barclays security: Your debit card ending 1496 was used fraudulently. Click is.gd/mX8pQr to dispute and secure acc0unt!      1      bank urgency   easy          1
# Name: count, Length: 2248, dtype: int64

# %%
X = train['text']
Y = train['label']

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, Y_train, Y_val = train_test_split(
    X,
    Y,
    test_size=0.2,
    random_state=64,
    stratify=Y
)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(
    ngram_range=(1,2),
    min_df=2,
    max_df=0.95,
    sublinear_tf= True
)

# %%
X_train_tfidf = vectorizer.fit_transform(X_train)
X_val_tfidf = vectorizer.transform(X_val)

# %%
import pickle

with open("vectorizer.pkl", "wb") as f:
    pickle.dump(vectorizer, f)

# %%
with open("vectorizer.pkl", "rb") as f:
    vectorizer = pickle.load(f)

# %%
from google.colab import files
files.download("vectorizer.pkl")

# %%
with open("vectorizer.pkl", "rb") as f:
    vec = pickle.load(f)

# %%
print(type(vec))
print(len(vec.vocabulary_))
# Out:
# <class 'sklearn.feature_extraction.text.TfidfVectorizer'>
# 4054
